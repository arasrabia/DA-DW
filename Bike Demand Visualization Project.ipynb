# %% [markdown]
# # WELCOME!

# %% [markdown]
# Welcome to **"Bike Demand Visualization Project"** which is the capstone project of Data Visualization Lessons . As you know recently, free or affordable access to bicycles has been provided for short-distance trips in an urban area as an alternative to motorized public transport or private vehicles. Thus, it is aimed to reduce traffic congestion, noise and air pollution.
#
# The aim of this project is to reveal the current patterns in the data by showing the historical data of London bike shares with visualization tools.
#
# This will allow us to X-ray the data as part of the EDA process before setting up a machine learning model.

# %% [markdown]
# ---
# ---

# %% [markdown]
# # #Determines
#
#
#
# #### Features
#
# - timestamp - timestamp field for grouping the data
# - cnt - the count of a new bike shares
# - t1 - real temperature in C
# - t2 - temperature in C “feels like”
# - hum - humidity in percentage
# - wind_speed - wind speed in km/h
# - weather_code - category of the weather
# - is_holiday - boolean field - 1 holiday / 0 non holiday
# - is_weekend - boolean field - 1 if the day is weekend
# - season - category field meteorological seasons: 0-spring ; 1-summer; 2-fall; 3-winter.
#
# **"weather_code" category description:**
# * 1 = Clear ; mostly clear but have some values with haze/fog/patches of fog/ fog in vicinity
# * 2 = scattered clouds / few clouds
# * 3 = Broken clouds
# * 4 = Cloudy
# * 7 = Rain/ light Rain shower/ Light rain
# * 10 = rain with thunderstorm
# * 26 = snowfall
# * 94 = Freezing Fog
# ---
#
# Initially, the task of discovering data will be waiting for you as always. Recognize features, detect missing values, outliers etc.  Review the data from various angles in different time breakdowns. For example, visualize the distribution of bike shares by day of the week. With this graph, you will be able to easily observe and make inferences how people's behavior changes daily. Likewise, you can make hourly, monthly, seasonally etc. analyzes. In addition, you can analyze correlation of variables with a heatmap.

# %% [markdown]
# # Tasks

# %% [markdown]
# ### 1.Import libraries

# %%
import numpy as np
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt

from pylab import rcParams
sns.set_style("darkgrid")

import warnings
warnings.filterwarnings("ignore")

# %% [markdown]
# ### 2.Read dataset

# %%
df=pd.read_csv('store_sharing.csv')
df.head()
# Out:
#              timestamp  cnt   t1   t2    hum  wind_speed  weather_code  \
# 0  2015-01-04 00:00:00  182  3.0  2.0   93.0         6.0           3.0
# 1  2015-01-04 01:00:00  138  3.0  2.5   93.0         5.0           1.0
# 2  2015-01-04 02:00:00  134  2.5  2.5   96.5         0.0           1.0
# 3  2015-01-04 03:00:00   72  2.0  2.0  100.0         0.0           1.0
# 4  2015-01-04 04:00:00   47  2.0  0.0   93.0         6.5           1.0
#
#    is_holiday  is_weekend  season
# 0         0.0         1.0     3.0
# 1         0.0         1.0     3.0
# 2         0.0         1.0     3.0
# 3         0.0         1.0     3.0
# 4         0.0         1.0     3.0

# %% [markdown]
# ### 3.Check missing values and if there are any dublicate rows or not.

# %%
df.duplicated().value_counts()
# Out:
# False    17414
# dtype: int64

# %%
df.isnull().sum()
# Out:
# timestamp       0
# cnt             0
# t1              0
# t2              0
# hum             0
# wind_speed      0
# weather_code    0
# is_holiday      0
# is_weekend      0
# season          0
# dtype: int64

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 17414 entries, 0 to 17413
# Data columns (total 10 columns):
#  #   Column        Non-Null Count  Dtype
# ---  ------        --------------  -----
#  0   timestamp     17414 non-null  object
#  1   cnt           17414 non-null  int64
#  2   t1            17414 non-null  float64
#  3   t2            17414 non-null  float64
#  4   hum           17414 non-null  float64
#  5   wind_speed    17414 non-null  float64
#  6   weather_code  17414 non-null  float64
#  7   is_holiday    17414 non-null  float64
#  8   is_weekend    17414 non-null  float64
#  9   season        17414 non-null  float64
# dtypes: float64(8), int64(1), object(1)
# memory usage: 1.3+ MB

# %%
df.describe().T
# Out:
#                 count         mean          std   min    25%    50%      75%  \
# cnt           17414.0  1143.101642  1085.108068   0.0  257.0  844.0  1671.75
# t1            17414.0    12.468091     5.571818  -1.5    8.0   12.5    16.00
# t2            17414.0    11.520836     6.615145  -6.0    6.0   12.5    16.00
# hum           17414.0    72.324954    14.313186  20.5   63.0   74.5    83.00
# wind_speed    17414.0    15.913063     7.894570   0.0   10.0   15.0    20.50
# weather_code  17414.0     2.722752     2.341163   1.0    1.0    2.0     3.00
# is_holiday    17414.0     0.022051     0.146854   0.0    0.0    0.0     0.00
# is_weekend    17414.0     0.285403     0.451619   0.0    0.0    0.0     1.00
# season        17414.0     1.492075     1.118911   0.0    0.0    1.0     2.00
#
#                  max
# cnt           7860.0
# t1              34.0
# t2              34.0
# hum            100.0
# wind_speed      56.5
# weather_code    26.0
# is_holiday       1.0
# is_weekend       1.0
# season           3.0

# %% [markdown]
# ### 4.Plot the distribution of various discrete features on (Season, haliday, weekend and weathercode)

# %%
# season
sns.countplot(x='season', data=df)
# Out:
# <AxesSubplot:xlabel='season', ylabel='count'>

# %%
# is_holiday
sns.countplot(x='is_holiday', data=df)
# Out:
# <AxesSubplot:xlabel='is_holiday', ylabel='count'>

# %%
# is_weekend
sns.countplot(x='is_weekend', data=df)
# Out:
# <AxesSubplot:xlabel='is_weekend', ylabel='count'>

# %%
# weather_code
sns.countplot(x='weather_code', data=df)
# Out:
# <AxesSubplot:xlabel='weather_code', ylabel='count'>

# %% [markdown]
# ### 5.Look at the data type of each variable, transform `timestamp` in type, and set it as index.

# %%
df.head(2)
# Out:
#             timestamp  cnt   t1   t2   hum  wind_speed  weather_code  \
# 0 2015-01-04 00:00:00  182  3.0  2.0  93.0         6.0           3.0
# 1 2015-01-04 01:00:00  138  3.0  2.5  93.0         5.0           1.0
#
#    is_holiday  is_weekend  season
# 0         0.0         1.0     3.0
# 1         0.0         1.0     3.0

# %%
df.timestamp = pd.to_datetime(df.timestamp)
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 17414 entries, 0 to 17413
# Data columns (total 10 columns):
#  #   Column        Non-Null Count  Dtype
# ---  ------        --------------  -----
#  0   timestamp     17414 non-null  datetime64[ns]
#  1   cnt           17414 non-null  int64
#  2   t1            17414 non-null  float64
#  3   t2            17414 non-null  float64
#  4   hum           17414 non-null  float64
#  5   wind_speed    17414 non-null  float64
#  6   weather_code  17414 non-null  float64
#  7   is_holiday    17414 non-null  float64
#  8   is_weekend    17414 non-null  float64
#  9   season        17414 non-null  float64
# dtypes: datetime64[ns](1), float64(8), int64(1)
# memory usage: 1.3 MB

# %%
df.set_index('timestamp', inplace=True)
df.head(2)
# Out:
#                      cnt   t1   t2   hum  wind_speed  weather_code  \
# timestamp
# 2015-01-04 00:00:00  182  3.0  2.0  93.0         6.0           3.0
# 2015-01-04 01:00:00  138  3.0  2.5  93.0         5.0           1.0
#
#                      is_holiday  is_weekend  season
# timestamp
# 2015-01-04 00:00:00         0.0         1.0     3.0
# 2015-01-04 01:00:00         0.0         1.0     3.0

# %% [markdown]
# - Tam 2 yillik bir timestamp var. `year, month, day_of_month, day_of_week, hour` bilgilerini alarak feature engineering yapalim

# %% [markdown]
# ### 6.Make feature engineering. Extract new columns (day of the week, day of the month, hour, month, season, year etc.)

# %% [markdown]
# you can use strftime('%Y-%m') for year_mount

# %%
def convert_time(dtobj):
    return dtobj.strftime('%Y-%m')

# %%
f = lambda x: x.strftime('%Y-%m')  #strftime.org
df['year_month']=  f(df.index)

df['year'] = df.index.year  # only apply to array
df['month'] = df.index.month
df['day_of_month'] = df.index.day
df['day_of_week'] = df.index.dayofweek
df['hour'] = df.index.hour

# %%
df.head()
# Out:
#                      cnt   t1   t2    hum  wind_speed  weather_code  \
# timestamp
# 2015-01-04 00:00:00  182  3.0  2.0   93.0         6.0           3.0
# 2015-01-04 01:00:00  138  3.0  2.5   93.0         5.0           1.0
# 2015-01-04 02:00:00  134  2.5  2.5   96.5         0.0           1.0
# 2015-01-04 03:00:00   72  2.0  2.0  100.0         0.0           1.0
# 2015-01-04 04:00:00   47  2.0  0.0   93.0         6.5           1.0
#
#                      is_holiday  is_weekend  season year_month  year  month  \
# timestamp
# 2015-01-04 00:00:00         0.0         1.0     3.0    2015-01  2015      1
# 2015-01-04 01:00:00         0.0         1.0     3.0    2015-01  2015      1
# 2015-01-04 02:00:00         0.0         1.0     3.0    2015-01  2015      1
# 2015-01-04 03:00:00         0.0         1.0     3.0    2015-01  2015      1
# 2015-01-04 04:00:00         0.0         1.0     3.0    2015-01  2015      1
#
#                      day_of_month  day_of_week  hour
# timestamp
# 2015-01-04 00:00:00             4            6     0
# 2015-01-04 01:00:00             4            6     1
# 2015-01-04 02:00:00             4            6     2
# 2015-01-04 03:00:00             4            6     3
# 2015-01-04 04:00:00             4            6     4

# %% [markdown]
# ### 7.Visualize the correlation with a heatmap

# %%
# for all variables 
plt.figure(figsize= (10, 6))
sns.heatmap(df.corr(), annot=True, fmt='.2f', cmap='coolwarm')
# Out:
# <AxesSubplot:>

# %%
pd.DataFrame(df.corr().cnt)
#df.corr().cnt
# Out:
#                    cnt
# cnt           1.000000
# t1            0.388798
# t2            0.369035
# hum          -0.462901
# wind_speed    0.116295
# weather_code -0.166633
# is_holiday   -0.051698
# is_weekend   -0.096499
# season       -0.116180
# year          0.010046
# month         0.063757
# day_of_month -0.017887
# day_of_week  -0.068688
# hour          0.324423

# %%
# for the target variable
plt.figure(figsize=(2, 7))
sns.heatmap(pd.DataFrame(df.corr().cnt), vmin=-1, vmax=1, fmt='.2f', cmap='BrBG')
# Out:
# <AxesSubplot:>

# %% [markdown]
# ### 8. Visualize the correlation of the target variable and the other features with barplot

# %%
#with pandas
plt.figure(figsize=(10,6))
df.corr()['cnt'].sort_values().plot.barh()
# Out:
# <AxesSubplot:>

# %% [markdown]
# ### 9.Plot bike shares over time use lineplot

# %%
plt.figure(figsize=(15, 5))
sns.lineplot(x=df.index, y='cnt', data=df)
# Out:
# <AxesSubplot:xlabel='timestamp', ylabel='cnt'>

# %%
df[df['cnt']<1000].sort_values('cnt')
# Out:
#                      cnt    t1    t2   hum  wind_speed  weather_code  \
# timestamp
# 2015-03-29 01:00:00    0  10.5   8.5  77.0        33.0           7.0
# 2016-11-21 03:00:00    9   6.0   3.5  93.0        12.0           7.0
# 2017-01-03 03:00:00   10   0.0  -4.0  93.0        13.0           1.0
# 2016-04-12 03:00:00   11   9.0   7.0  87.0        14.0           7.0
# 2016-02-16 03:00:00   12   0.5  -0.5  90.0         5.0           1.0
# ...                  ...   ...   ...   ...         ...           ...
# 2016-06-29 21:00:00  999  16.0  16.0  77.0        20.0           2.0
# 2015-01-27 12:00:00  999   9.0   6.0  66.0        17.0           2.0
# 2016-05-05 21:00:00  999  13.0  13.0  57.0        14.0           1.0
# 2016-11-03 20:00:00  999  10.0   8.0  71.0        16.0           1.0
# 2016-04-01 10:00:00  999  10.5   9.5  52.0        12.0           1.0
#
#                      is_holiday  is_weekend  season year_month  year  month  \
# timestamp
# 2015-03-29 01:00:00         0.0         1.0     0.0    2015-03  2015      3
# 2016-11-21 03:00:00         0.0         0.0     2.0    2016-11  2016     11
# 2017-01-03 03:00:00         0.0         0.0     3.0    2017-01  2017      1
# 2016-04-12 03:00:00         0.0         0.0     0.0    2016-04  2016      4
# 2016-02-16 03:00:00         0.0         0.0     3.0    2016-02  2016      2
# ...                         ...         ...     ...        ...   ...    ...
# 2016-06-29 21:00:00         0.0         0.0     1.0    2016-06  2016      6
# 2015-01-27 12:00:00         0.0         0.0     3.0    2015-01  2015      1
# 2016-05-05 21:00:00         0.0         0.0     0.0    2016-05  2016      5
# 2016-11-03 20:00:00         0.0         0.0     2.0    2016-11  2016     11
# 2016-04-01 10:00:00         0.0         0.0     0.0    2016-04  2016      4
#
#                      day_of_month  day_of_week  hour
# timestamp
# 2015-03-29 01:00:00            29            6     1
# 2016-11-21 03:00:00            21            0     3
# 2017-01-03 03:00:00             3            1     3
# 2016-04-12 03:00:00            12            1     3
# 2016-02-16 03:00:00            16            1     3
# ...                           ...          ...   ...
# 2016-06-29 21:00:00            29            2    21
# 2015-01-27 12:00:00            27            1    12
# 2016-05-05 21:00:00             5            3    21
# 2016-11-03 20:00:00             3            3    20
# 2016-04-01 10:00:00             1            4    10
#
# [9739 rows x 15 columns]

# %%
df[df['cnt']>6000].sort_values('cnt', ascending=False)
# Out:
#                       cnt    t1    t2   hum  wind_speed  weather_code  \
# timestamp
# 2015-07-09 17:00:00  7860  23.0  22.0  27.0        11.0           1.0
# 2015-07-09 08:00:00  7531  14.5  14.5  61.0        19.0           2.0
# 2015-08-06 17:00:00  7208  22.5  22.5  55.0        17.5           2.0
# 2015-07-09 18:00:00  6913  22.5  21.5  29.0        13.0           1.0
# 2015-08-06 08:00:00  6585  19.0  19.0  78.0        12.0           7.0
# 2015-08-06 18:00:00  6394  21.5  21.5  58.5        20.0           2.0
# 2015-07-09 16:00:00  6033  23.0  22.0  26.0        11.0           1.0
#
#                      is_holiday  is_weekend  season year_month  year  month  \
# timestamp
# 2015-07-09 17:00:00         0.0         0.0     1.0    2015-07  2015      7
# 2015-07-09 08:00:00         0.0         0.0     1.0    2015-07  2015      7
# 2015-08-06 17:00:00         0.0         0.0     1.0    2015-08  2015      8
# 2015-07-09 18:00:00         0.0         0.0     1.0    2015-07  2015      7
# 2015-08-06 08:00:00         0.0         0.0     1.0    2015-08  2015      8
# 2015-08-06 18:00:00         0.0         0.0     1.0    2015-08  2015      8
# 2015-07-09 16:00:00         0.0         0.0     1.0    2015-07  2015      7
#
#                      day_of_month  day_of_week  hour
# timestamp
# 2015-07-09 17:00:00             9            3    17
# 2015-07-09 08:00:00             9            3     8
# 2015-08-06 17:00:00             6            3    17
# 2015-07-09 18:00:00             9            3    18
# 2015-08-06 08:00:00             6            3     8
# 2015-08-06 18:00:00             6            3    18
# 2015-07-09 16:00:00             9            3    16

# %%
fig, ax = plt.subplots()
sns.lineplot(x='t1', y='cnt', data=df [(df.hour==8)], hue='is_weekend' )
# Out:
# <AxesSubplot:xlabel='t1', ylabel='cnt'>

# %% [markdown]
# ### 10.Plot bike shares by months and year_of_month (use lineplot, pointplot, barplot)

# %%
df_sum=pd.DataFrame(df.groupby('year_month').cnt.sum())
df_sum.head(3)
# Out:
#                cnt
# year_month
# 2015-01     546639
# 2015-02     543594
# 2015-03     695934

# %%
plt.figure(figsize=(20, 5))
sns.lineplot(x='year_month', y='cnt',data=df_sum)
plt.xticks(rotation=90);

# %%
df_sum.head()
# Out:
#                cnt
# year_month
# 2016-09     998619
# 2016-10     935706
# 2016-11     703859
# 2016-12     651908
# 2017-01      37680

# %%
df.head()
# Out:
#                      cnt   t1   t2    hum  wind_speed  weather_code  \
# timestamp
# 2015-01-04 00:00:00  182  3.0  2.0   93.0         6.0           3.0
# 2015-01-04 01:00:00  138  3.0  2.5   93.0         5.0           1.0
# 2015-01-04 02:00:00  134  2.5  2.5   96.5         0.0           1.0
# 2015-01-04 03:00:00   72  2.0  2.0  100.0         0.0           1.0
# 2015-01-04 04:00:00   47  2.0  0.0   93.0         6.5           1.0
#
#                      is_holiday  is_weekend  season year_month  year  month  \
# timestamp
# 2015-01-04 00:00:00         0.0         1.0     3.0    2015-01  2015      1
# 2015-01-04 01:00:00         0.0         1.0     3.0    2015-01  2015      1
# 2015-01-04 02:00:00         0.0         1.0     3.0    2015-01  2015      1
# 2015-01-04 03:00:00         0.0         1.0     3.0    2015-01  2015      1
# 2015-01-04 04:00:00         0.0         1.0     3.0    2015-01  2015      1
#
#                      day_of_month  day_of_week  hour
# timestamp
# 2015-01-04 00:00:00             4            6     0
# 2015-01-04 01:00:00             4            6     1
# 2015-01-04 02:00:00             4            6     2
# 2015-01-04 03:00:00             4            6     3
# 2015-01-04 04:00:00             4            6     4

# %%
df.tail()
# Out:
#                       cnt   t1   t2   hum  wind_speed  weather_code  \
# timestamp
# 2017-01-03 19:00:00  1042  5.0  1.0  81.0        19.0           3.0
# 2017-01-03 20:00:00   541  5.0  1.0  81.0        21.0           4.0
# 2017-01-03 21:00:00   337  5.5  1.5  78.5        24.0           4.0
# 2017-01-03 22:00:00   224  5.5  1.5  76.0        23.0           4.0
# 2017-01-03 23:00:00   139  5.0  1.0  76.0        22.0           2.0
#
#                      is_holiday  is_weekend  season year_month  year  month  \
# timestamp
# 2017-01-03 19:00:00         0.0         0.0     3.0    2017-01  2017      1
# 2017-01-03 20:00:00         0.0         0.0     3.0    2017-01  2017      1
# 2017-01-03 21:00:00         0.0         0.0     3.0    2017-01  2017      1
# 2017-01-03 22:00:00         0.0         0.0     3.0    2017-01  2017      1
# 2017-01-03 23:00:00         0.0         0.0     3.0    2017-01  2017      1
#
#                      day_of_month  day_of_week  hour
# timestamp
# 2017-01-03 19:00:00             3            1    19
# 2017-01-03 20:00:00             3            1    20
# 2017-01-03 21:00:00             3            1    21
# 2017-01-03 22:00:00             3            1    22
# 2017-01-03 23:00:00             3            1    23

# %%
# with pointplot
plt.figure(figsize=(15,5))
sns.pointplot(x='month', y= 'cnt', data=df)
# Out:
# <AxesSubplot:xlabel='month', ylabel='cnt'>

# %%
# with barplot
plt.figure(figsize=(14,6))
sns.barplot(x='month', y='cnt', data=df)
# Out:
# <AxesSubplot:xlabel='month', ylabel='cnt'>

# %% [markdown]
# ### 11.Plot bike shares by hours on (holidays, weekend, season)

# %%
df.head()
# Out:
#                      cnt   t1   t2    hum  wind_speed  weather_code  \
# timestamp
# 2015-01-04 00:00:00  182  3.0  2.0   93.0         6.0           3.0
# 2015-01-04 01:00:00  138  3.0  2.5   93.0         5.0           1.0
# 2015-01-04 02:00:00  134  2.5  2.5   96.5         0.0           1.0
# 2015-01-04 03:00:00   72  2.0  2.0  100.0         0.0           1.0
# 2015-01-04 04:00:00   47  2.0  0.0   93.0         6.5           1.0
#
#                      is_holiday  is_weekend  season year_month  year  month  \
# timestamp
# 2015-01-04 00:00:00         0.0         1.0     3.0    2015-01  2015      1
# 2015-01-04 01:00:00         0.0         1.0     3.0    2015-01  2015      1
# 2015-01-04 02:00:00         0.0         1.0     3.0    2015-01  2015      1
# 2015-01-04 03:00:00         0.0         1.0     3.0    2015-01  2015      1
# 2015-01-04 04:00:00         0.0         1.0     3.0    2015-01  2015      1
#
#                      day_of_month  day_of_week  hour
# timestamp
# 2015-01-04 00:00:00             4            6     0
# 2015-01-04 01:00:00             4            6     1
# 2015-01-04 02:00:00             4            6     2
# 2015-01-04 03:00:00             4            6     3
# 2015-01-04 04:00:00             4            6     4

# %%
# with lineplot (*whether it is a holiday or not*)
plt.figure(figsize=(12,6))
sns.lineplot(x='hour', y='cnt', hue='is_holiday', data=df)
# Out:
# <AxesSubplot:xlabel='hour', ylabel='cnt'>

# %%
df['is_workday'] = (df['is_weekend']==1) | (df['is_holiday']==1)
plt.figure(figsize=(12,6))
sns.lineplot(x='hour', y='cnt', hue='is_workday', data=df)
# Out:
# <AxesSubplot:xlabel='hour', ylabel='cnt'>

# %%
# with lineplot (*You may want to see seasonal breakdowns*)
plt.figure(figsize=(15,6))
sns.lineplot(data=df, x='hour', y='cnt', hue='season')
# Out:
# <AxesSubplot:xlabel='hour', ylabel='cnt'>

# %%
plt.figure(figsize=(15,6))
sns.lineplot(data=df, x='hour', y='cnt', hue='season', palette=['r', 'g', 'b', 'k'])
# Out:
# <AxesSubplot:xlabel='hour', ylabel='cnt'>

# %%
# with pointplot
fig,(ax1, ax2, ax3, ax4)= plt.subplots(nrows=4, figsize=(18,15)  )

sns.pointplot(data=df, x='hour', y='cnt', ax=ax1)
sns.pointplot(data=df, x='hour', y='cnt', hue='is_holiday', ax=ax2)
sns.pointplot(data=df, x='hour', y='cnt', hue='is_weekend', ax=ax3)
sns.pointplot(data=df, x='hour', y='cnt', hue='season', ax=ax4);

# %% [markdown]
# ### 12.Plot bike shares by day of week
# - You may want to see whether it is a holiday or not

# %%
# with barplot
plt.figure(figsize=(7, 4))
sns.barplot(x='day_of_week', y='cnt', data=df, hue='is_weekend')
# Out:
# <AxesSubplot:xlabel='day_of_week', ylabel='cnt'>

# %%
# with pointplot
# with barplot
plt.figure(figsize=(7, 4))
sns.pointplot(x='day_of_week', y='cnt', data=df, hue='is_weekend')
# Out:
# <AxesSubplot:xlabel='day_of_week', ylabel='cnt'>

# %% [markdown]
# ### 13.Plot bike shares by day of month

# %%
#with lineplot
plt.figure(figsize=(15, 5))
sns.lineplot(x='day_of_month', y='cnt', data=df)
pd.DataFrame(df.groupby('day_of_month').cnt.mean())
# Out:
#                       cnt
# day_of_month
# 1             1077.455652
# 2             1088.117754
# 3             1127.602837
# 4             1144.492174
# 5             1140.772727
# 6             1211.227431
# 7             1194.151832
# 8             1222.696491
# 9             1261.260870
# 10            1157.453913
# 11            1203.618467
# 12            1166.952212
# 13            1139.221441
# 14            1123.670139
# 15            1175.629565
# 16            1140.871080
# 17            1182.311847
# 18            1178.552632
# 19            1153.147826
# 20            1115.667832
# 21            1125.729167
# 22            1127.717014
# 23            1173.994792
# 24            1054.147950
# 25            1190.786087
# 26            1081.516637
# 27            1130.681979
# 28            1062.750871
# 29            1079.680581
# 30            1156.406844
# 31             968.187311

# %% [markdown]
# ### 14.Plot bike shares by year
# ### Plot bike shares on holidays by seasons

# %%
# with barplot
plt.figure(figsize=(10,6))
sns.barplot(x="year",y="cnt",data=df);

# %%
sns.barplot(x="season",y="cnt", data = df[df["is_holiday"]==1]);

# %%
# with barplot

# %% [markdown]
# ### 15.Visualize the distribution of bike shares by weekday/weekend with piechart and barplot

# %%
# pie chart
fig, ax = plt.subplots(figsize=(5,5))
ax.pie(x=df.is_weekend.value_counts().values, 
       labels=['weekday','weekend'], 
       autopct='%.1f%%',    
       )
plt.show()

# %%
# with countplot

fig, ax = plt.subplots(figsize=(7,5))
ax = sns.countplot(x='is_weekend',data=df)

for bar in ax.patches: 
        ax.annotate(  "%"+str(round(100*bar.get_height()/len(df),1)) +' - '+ str(bar.get_height() ), 
                    (bar.get_x()+0.2 , bar.get_height()+10) ,
                    size=12)

# %% [markdown]
# ### 16.Plot the distribution of weather code by seasons

# %%
# with countplot
# with seaborn countplot
sns.countplot(x="weather_code",data=df);

# %%
# with catplot
g = sns.catplot(x="weather_code", col="season", data=df, kind='count')

# %%
plt.figure(figsize=(15,10))

plt.subplot(211)
plt.title("t1 distribution According to humudity")
sns.scatterplot(x="t1",y="hum",data=df, hue='season',palette="coolwarm")

plt.subplot(212)
plt.title("t1 distribution According to wind speed")
sns.scatterplot(x="t1",y="wind_speed",data=df, hue='season',palette="coolwarm");
